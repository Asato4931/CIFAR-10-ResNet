# %% [markdown]
# <h1>モジュールのインストール</h1>

# %%
# !pip install torch torchvision

import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.15.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# <h1>データの準備</h1>

# %%
import torch
import torchvision
from torchvision import transforms

transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])


transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])



train_dataset = torchvision.datasets. CIFAR10(
    './cifar-10', train=True, download=True,
    transform=transform_train)


test_data = torchvision.datasets. CIFAR10(
    './cifar-10', train=False, download=True,
    transform=transform_test)

# train_dataをshuffleしてから分割

train_data, val_data = torch.utils.data.random_split(train_dataset, [45000, 5000])

train_loader = torch.utils.data.DataLoader(train_data,  batch_size=128, shuffle = True, num_workers = 2)
val_loader = torch.utils.data.DataLoader(val_data, batch_size = 128)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:02<00:00, 63283223.65it/s]
# Extracting ./cifar-10/cifar-10-python.tar.gz to ./cifar-10
# Files already downloaded and verified

# %% [markdown]
# <h1>Plain Net 20 アーキテクチャ</h1>

# %%
#シードの固定

torch.manual_seed(4931)


class PlainNet20(nn.Module):
    def __init__(self):
        super(PlainNet20, self).__init__()
        # Input size: [batch_size, 3, 32, 32] -> Output Size : [batch_size, 16, 32, 32]
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size= 3, padding = 1)

        self.bn1 = nn.BatchNorm2d(16)

        # Input size: [batch_size, 16, 32, 32] -> Output Size : [batch_size, 16, 32, 32]
        self.conv2_1 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_2 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_3 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_4 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_5 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_6 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)

        self.bn2_1 = nn.BatchNorm2d(16)
        self.bn2_2 = nn.BatchNorm2d(16)
        self.bn2_3 = nn.BatchNorm2d(16)
        self.bn2_4 = nn.BatchNorm2d(16)
        self.bn2_5 = nn.BatchNorm2d(16)
        self.bn2_6 = nn.BatchNorm2d(16)

        # Input size: [batch_size, 16, 32, 32] -> Output Size : [batch_size, 32, 16, 16]
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1,stride = 2)

        self.bn3 = nn.BatchNorm2d(32)

        # Input size: [batch_size, 32, 16, 16] -> Output Size : [batch_size, 32, 16, 16]
        self.conv4_1 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_2= nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_3 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_4 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_5 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)

        self.bn4_1 = nn.BatchNorm2d(32)
        self.bn4_2 = nn.BatchNorm2d(32)
        self.bn4_3 = nn.BatchNorm2d(32)
        self.bn4_4 = nn.BatchNorm2d(32)
        self.bn4_5 = nn.BatchNorm2d(32)


        # Input size: [batch_size, 32, 16, 16] -> Output Size : [batch_size, 64, 8, 8]
        self.conv5 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1, stride = 2)

        self.bn5 = nn.BatchNorm2d(64)

        # Input size: [batch_size, 64, 8, 8] -> Output Size : [batch_size, 64, 8, 8]
        self.conv6_1 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_5 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)


        self.bn6_1 = nn.BatchNorm2d(64)
        self.bn6_2 = nn.BatchNorm2d(64)
        self.bn6_3 = nn.BatchNorm2d(64)
        self.bn6_4 = nn.BatchNorm2d(64)



        # Global Average Pooling
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1,1))
        # Size after pooling: [batch_size, 64, 1, 1]

        self.fc = nn.Linear(in_features=64, out_features=10)



    def forward(self, x):

        x = F.relu(self.bn1(self.conv1(x)))

        x = F.relu(self.bn2_1(self.conv2_1(x)))
        x = F.relu(self.bn2_2(self.conv2_2(x)))
        x = F.relu(self.bn2_3(self.conv2_3(x)))
        x = F.relu(self.bn2_4(self.conv2_4(x)))
        x = F.relu(self.bn2_5(self.conv2_5(x)))
        x = F.relu(self.bn2_6(self.conv2_6(x)))

        x = F.relu(self.bn3(self.conv3(x)))

        x = F.relu(self.bn4_1(self.conv4_1(x)))
        x = F.relu(self.bn4_2(self.conv4_2(x)))
        x = F.relu(self.bn4_3(self.conv4_3(x)))
        x = F.relu(self.bn4_4(self.conv4_4(x)))
        x = F.relu(self.bn4_5(self.conv4_5(x)))


        x = F.relu(self.bn5(self.conv5(x)))

        x = F.relu(self.bn6_1(self.conv6_1(x)))
        x = F.relu(self.bn6_2(self.conv6_2(x)))
        x = F.relu(self.bn6_3(self.conv6_3(x)))
        x = F.relu(self.bn6_4(self.conv6_4(x)))

        x = F.relu(self.conv6_5(x))

        x = self.avgpool(x)

        x = x.view(-1, 64)
        x = self.fc(x)

        return x



# Instantiate the network
plain_net20 = PlainNet20()

# データ並列学習 ON

plain_net20.to(device)

plain_net20 = nn.DataParallel(plain_net20)

# %% [markdown]
# <h1>Plain Net 56 アーキテクチャ</h1>

# %%
#シードの固定

torch.manual_seed(4931)


class PlainNet56(nn.Module):
    def __init__(self):
        super(PlainNet56, self).__init__()
        # Input size: [batch_size, 3, 32, 32] -> Output Size : [batch_size, 16, 32, 32]
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size= 3, padding = 1)

        self.bn1 = nn.BatchNorm2d(16)

        # Input size: [batch_size, 16, 32, 32] -> Output Size : [batch_size, 16, 32, 32]
        self.conv2_1 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_2 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_3 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_4 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_5 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_6 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_7 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_8 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_9 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_10 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_11 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_12 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_13 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_14 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_15 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_16 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_17 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.conv2_18 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)

        self.bn2_1 = nn.BatchNorm2d(16)
        self.bn2_2 = nn.BatchNorm2d(16)
        self.bn2_3 = nn.BatchNorm2d(16)
        self.bn2_4 = nn.BatchNorm2d(16)
        self.bn2_5 = nn.BatchNorm2d(16)
        self.bn2_6 = nn.BatchNorm2d(16)
        self.bn2_7 = nn.BatchNorm2d(16)
        self.bn2_8 = nn.BatchNorm2d(16)
        self.bn2_9 = nn.BatchNorm2d(16)
        self.bn2_10 = nn.BatchNorm2d(16)
        self.bn2_11 = nn.BatchNorm2d(16)
        self.bn2_12 = nn.BatchNorm2d(16)
        self.bn2_13 = nn.BatchNorm2d(16)
        self.bn2_14 = nn.BatchNorm2d(16)
        self.bn2_15 = nn.BatchNorm2d(16)
        self.bn2_16 = nn.BatchNorm2d(16)
        self.bn2_17 = nn.BatchNorm2d(16)
        self.bn2_18 = nn.BatchNorm2d(16)

        # Input size: [batch_size, 16, 32, 32] -> Output Size : [batch_size, 32, 16, 16]
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1,stride = 2)

        self.bn3 = nn.BatchNorm2d(32)

        # Input size: [batch_size, 32, 16, 16] -> Output Size : [batch_size, 32, 16, 16]
        self.conv4_1 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_2= nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_3 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_4 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_5 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_6 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_7= nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_8 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_9 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_10 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_11 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_12= nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_13 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_14 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_15 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_16 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv4_17 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)


        self.bn4_1 = nn.BatchNorm2d(32)
        self.bn4_2 = nn.BatchNorm2d(32)
        self.bn4_3 = nn.BatchNorm2d(32)
        self.bn4_4 = nn.BatchNorm2d(32)
        self.bn4_5 = nn.BatchNorm2d(32)
        self.bn4_6 = nn.BatchNorm2d(32)
        self.bn4_7 = nn.BatchNorm2d(32)
        self.bn4_8 = nn.BatchNorm2d(32)
        self.bn4_9 = nn.BatchNorm2d(32)
        self.bn4_10 = nn.BatchNorm2d(32)
        self.bn4_11 = nn.BatchNorm2d(32)
        self.bn4_12 = nn.BatchNorm2d(32)
        self.bn4_13 = nn.BatchNorm2d(32)
        self.bn4_14 = nn.BatchNorm2d(32)
        self.bn4_15 = nn.BatchNorm2d(32)
        self.bn4_16 = nn.BatchNorm2d(32)
        self.bn4_17 = nn.BatchNorm2d(32)


        # Input size: [batch_size, 32, 16, 16] -> Output Size : [batch_size, 64, 8, 8]
        self.conv5 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1, stride = 2)

        self.bn5 = nn.BatchNorm2d(64)

        # Input size: [batch_size, 64, 8, 8] -> Output Size : [batch_size, 64, 8, 8]
        self.conv6_1 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_5 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_6 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_7 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_8 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_9 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_10 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_11 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_12 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_13 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_14 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_15 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_16 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv6_17 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)


        self.bn6_1 = nn.BatchNorm2d(64)
        self.bn6_2 = nn.BatchNorm2d(64)
        self.bn6_3 = nn.BatchNorm2d(64)
        self.bn6_4 = nn.BatchNorm2d(64)
        self.bn6_5 = nn.BatchNorm2d(64)
        self.bn6_6 = nn.BatchNorm2d(64)
        self.bn6_7 = nn.BatchNorm2d(64)
        self.bn6_8 = nn.BatchNorm2d(64)
        self.bn6_9 = nn.BatchNorm2d(64)
        self.bn6_10 = nn.BatchNorm2d(64)
        self.bn6_11 = nn.BatchNorm2d(64)
        self.bn6_12 = nn.BatchNorm2d(64)
        self.bn6_13 = nn.BatchNorm2d(64)
        self.bn6_14 = nn.BatchNorm2d(64)
        self.bn6_15 = nn.BatchNorm2d(64)
        self.bn6_16 = nn.BatchNorm2d(64)



        # Global Average Pooling
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1,1))
        # Size after pooling: [batch_size, 64, 1, 1]

        self.fc = nn.Linear(in_features=64, out_features=10)



    def forward(self, x):

        x = F.relu(self.bn1(self.conv1(x)))

        x = F.relu(self.bn2_1(self.conv2_1(x)))
        x = F.relu(self.bn2_2(self.conv2_2(x)))
        x = F.relu(self.bn2_3(self.conv2_3(x)))
        x = F.relu(self.bn2_4(self.conv2_4(x)))
        x = F.relu(self.bn2_5(self.conv2_5(x)))
        x = F.relu(self.bn2_6(self.conv2_6(x)))
        x = F.relu(self.bn2_7(self.conv2_7(x)))
        x = F.relu(self.bn2_8(self.conv2_8(x)))
        x = F.relu(self.bn2_9(self.conv2_9(x)))
        x = F.relu(self.bn2_10(self.conv2_10(x)))
        x = F.relu(self.bn2_11(self.conv2_11(x)))
        x = F.relu(self.bn2_12(self.conv2_12(x)))
        x = F.relu(self.bn2_13(self.conv2_13(x)))
        x = F.relu(self.bn2_14(self.conv2_14(x)))
        x = F.relu(self.bn2_15(self.conv2_15(x)))
        x = F.relu(self.bn2_16(self.conv2_16(x)))
        x = F.relu(self.bn2_17(self.conv2_17(x)))
        x = F.relu(self.bn2_18(self.conv2_18(x)))

        x = F.relu(self.bn3(self.conv3(x)))

        x = F.relu(self.bn4_1(self.conv4_1(x)))
        x = F.relu(self.bn4_2(self.conv4_2(x)))
        x = F.relu(self.bn4_3(self.conv4_3(x)))
        x = F.relu(self.bn4_4(self.conv4_4(x)))
        x = F.relu(self.bn4_5(self.conv4_5(x)))
        x = F.relu(self.bn4_6(self.conv4_6(x)))
        x = F.relu(self.bn4_7(self.conv4_7(x)))
        x = F.relu(self.bn4_8(self.conv4_8(x)))
        x = F.relu(self.bn4_9(self.conv4_9(x)))
        x = F.relu(self.bn4_10(self.conv4_10(x)))
        x = F.relu(self.bn4_11(self.conv4_11(x)))
        x = F.relu(self.bn4_12(self.conv4_12(x)))
        x = F.relu(self.bn4_13(self.conv4_13(x)))
        x = F.relu(self.bn4_14(self.conv4_14(x)))
        x = F.relu(self.bn4_15(self.conv4_15(x)))
        x = F.relu(self.bn4_16(self.conv4_16(x)))
        x = F.relu(self.bn4_17(self.conv4_17(x)))


        x = F.relu(self.bn5(self.conv5(x)))

        x = F.relu(self.bn6_1(self.conv6_1(x)))
        x = F.relu(self.bn6_2(self.conv6_2(x)))
        x = F.relu(self.bn6_3(self.conv6_3(x)))
        x = F.relu(self.bn6_4(self.conv6_4(x)))
        x = F.relu(self.bn6_5(self.conv6_5(x)))
        x = F.relu(self.bn6_6(self.conv6_6(x)))
        x = F.relu(self.bn6_7(self.conv6_7(x)))
        x = F.relu(self.bn6_8(self.conv6_8(x)))
        x = F.relu(self.bn6_9(self.conv6_9(x)))
        x = F.relu(self.bn6_10(self.conv6_10(x)))
        x = F.relu(self.bn6_11(self.conv6_11(x)))
        x = F.relu(self.bn6_12(self.conv6_12(x)))
        x = F.relu(self.bn6_13(self.conv6_13(x)))
        x = F.relu(self.bn6_14(self.conv6_14(x)))
        x = F.relu(self.bn6_15(self.conv6_15(x)))
        x = F.relu(self.bn6_16(self.conv6_16(x)))


        x = F.relu(self.conv6_17(x))

        x = self.avgpool(x)

        x = x.view(-1, 64)
        x = self.fc(x)

        return x

# Instantiate the network
plain_net56 = PlainNet56()



# データ並列学習 ON
plain_net56.to(device)

plain_net56 = nn.DataParallel(plain_net56)

# %% [markdown]
# <h1>損失関数の定義</h1>

# %%
# 交差エントロピー
criterion = nn.CrossEntropyLoss()
# 確率的勾配降下法
optimizer_20 = optim.SGD(plain_net20.parameters(), lr=0.1, momentum=0.9, weight_decay = 0.0001)
optimizer_56 = optim.SGD(plain_net56.parameters(), lr=0.1, momentum=0.9, weight_decay = 0.0001)

# %% [markdown]
# <h1>Plain Net 20 学習</h1>

# %%
num_epochs = 182

train_losses_20 = []
val_losses_20 = []
train_accuracies_20 = []
val_accuracies_20 = []

train_losses_56 = []
val_losses_56 = []
train_accuracies_56 = []
val_accuracies_56 = []


## Train Plain Net 20

t0 = time.time()

for epoch in range(num_epochs):
    # Training
    plain_net20.train()  # Set the model to training mode
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    if num_epochs == 92:

        optimizer_20 = optim.SGD(plain_net20.parameters(), lr = 0.01, momentum = 0.9, weight_decay = 0.0001)


    for data in train_loader:                                     #enumerateでバッチに番号を振り、iでそれを引っ張ってくる。dataは一個ずつ引っ張り出してくるのではなく一気にバッチで学習する。
        inputs, labels = data                                     #画像データ,正解ラベルのペアになっているのを分解
        inputs, labels = inputs.to(device), labels.to(device)     #GPUに載せる
        optimizer_20.zero_grad()                                     #勾配を0に設定
        outputs = plain_net20(inputs)                                     #インスタンス化したモデルに、入力を加えることで主力を得る
        loss = criterion(outputs, labels)                         #指定した損失関数から損失を得る。この時点ではテンソルであることに注意。
        loss.backward()                                           #得た損失のテンソルから勾配を計算
        optimizer_20.step()                                          #得た勾配からパラメータを更新

        running_loss += loss.item()                               #各データの損失を、テンソルから普通の数字(フロート)に変換し、epochごとの損失を得るために足し合わせる。
        _, predicted = torch.max(outputs.data, 1)                 # 1:データの各クラス間 の最大値を、確率とその値を返す。
        total_train += labels.size(0)                             # バッチに含まれているデータの数を継ぎ足す。
        correct_train += (predicted == labels).sum().item()       # 正解した分のみを正答数に継ぎ足す。

    train_losses_20.append(running_loss / len(train_loader))         # epochごとに、平均損失リストに加えていく。
    train_accuracies_20.append(100 * correct_train / total_train)    # epochごとに正答率リストに加えていく。

    # Validation
    plain_net20.eval()  # Set the model to evaluation mode
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for data in val_loader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = plain_net20(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_losses_20.append(val_loss / len(val_loader))
    val_accuracies_20.append(100 * correct_val / total_val)

    print(f'Epoch {epoch+1}/{num_epochs}')
    print(f'Training loss: {train_losses_20[-1]:.3f}, Training accuracy: {train_accuracies_20[-1]:.3f}%')
    print(f'Validation loss: {val_losses_20[-1]:.3f}, Validation accuracy: {val_accuracies_20[-1]:.3f}%')

print('Plain Net 20 Finished Training')
print("Training time(seconds):", time.time()-t0)
# Out:
# Epoch 1/182
# Training loss: 1.810, Training accuracy: 30.482%
# Validation loss: 1.844, Validation accuracy: 33.000%
# Epoch 2/182
# Training loss: 1.560, Training accuracy: 41.560%
# Validation loss: 1.467, Validation accuracy: 46.080%
# Epoch 3/182
# Training loss: 1.298, Training accuracy: 52.533%
# Validation loss: 1.731, Validation accuracy: 45.960%
# Epoch 4/182
# Training loss: 1.093, Training accuracy: 60.729%
# Validation loss: 1.584, Validation accuracy: 52.100%
# Epoch 5/182
# Training loss: 0.963, Training accuracy: 65.758%
# Validation loss: 1.065, Validation accuracy: 62.760%
# Epoch 6/182
# Training loss: 0.855, Training accuracy: 70.133%
# Validation loss: 1.080, Validation accuracy: 63.460%
# Epoch 7/182
# Training loss: 0.773, Training accuracy: 73.267%
# Validation loss: 1.021, Validation accuracy: 64.580%
# Epoch 8/182
# Training loss: 0.718, Training accuracy: 75.036%
# Validation loss: 1.085, Validation accuracy: 65.040%
# Epoch 9/182
# Training loss: 0.672, Training accuracy: 76.876%
# Validation loss: 0.852, Validation accuracy: 71.580%
# Epoch 10/182
# Training loss: 0.625, Training accuracy: 78.578%
# Validation loss: 0.788, Validation accuracy: 74.080%
# Epoch 11/182
# Training loss: 0.592, Training accuracy: 79.607%
# Validation loss: 0.666, Validation accuracy: 76.980%
# Epoch 12/182
# Training loss: 0.569, Training accuracy: 80.424%
# Validation loss: 0.835, Validation accuracy: 73.100%
# Epoch 13/182
# Training loss: 0.542, Training accuracy: 81.280%
# Validation loss: 0.696, Validation accuracy: 77.040%
# Epoch 14/182
# Training loss: 0.521, Training accuracy: 82.056%
# Validation loss: 0.786, Validation accuracy: 74.440%
# Epoch 15/182
# Training loss: 0.504, Training accuracy: 82.569%
# Validation loss: 0.726, Validation accuracy: 75.260%
# Epoch 16/182
# Training loss: 0.485, Training accuracy: 83.264%
# Validation loss: 0.634, Validation accuracy: 79.020%
# Epoch 17/182
# Training loss: 0.472, Training accuracy: 83.649%
# Validation loss: 0.592, Validation accuracy: 79.820%
# Epoch 18/182
# Training loss: 0.457, Training accuracy: 84.151%
# Validation loss: 0.659, Validation accuracy: 77.380%
# Epoch 19/182
# Training loss: 0.445, Training accuracy: 84.604%
# Validation loss: 0.613, Validation accuracy: 79.180%
# Epoch 20/182
# Training loss: 0.432, Training accuracy: 85.093%
# Validation loss: 0.695, Validation accuracy: 77.360%
# Epoch 21/182
# Training loss: 0.419, Training accuracy: 85.484%
# Validation loss: 0.643, Validation accuracy: 78.660%
# Epoch 22/182
# Training loss: 0.405, Training accuracy: 85.989%
# Validation loss: 0.632, Validation accuracy: 78.680%
# Epoch 23/182
# Training loss: 0.403, Training accuracy: 86.107%
# Validation loss: 0.506, Validation accuracy: 83.060%
# Epoch 24/182
# Training loss: 0.395, Training accuracy: 86.180%
# Validation loss: 0.587, Validation accuracy: 80.620%
# Epoch 25/182
# Training loss: 0.376, Training accuracy: 86.882%
# Validation loss: 0.581, Validation accuracy: 80.640%
# Epoch 26/182
# Training loss: 0.376, Training accuracy: 86.984%
# Validation loss: 0.557, Validation accuracy: 81.580%
# Epoch 27/182
# Training loss: 0.357, Training accuracy: 87.498%
# Validation loss: 0.628, Validation accuracy: 79.820%
# Epoch 28/182
# Training loss: 0.357, Training accuracy: 87.562%
# Validation loss: 0.532, Validation accuracy: 82.560%
# Epoch 29/182
# Training loss: 0.354, Training accuracy: 87.742%
# Validation loss: 0.634, Validation accuracy: 79.200%
# Epoch 30/182
# Training loss: 0.352, Training accuracy: 87.813%
# Validation loss: 0.547, Validation accuracy: 81.900%
# Epoch 31/182
# Training loss: 0.342, Training accuracy: 88.133%
# Validation loss: 0.505, Validation accuracy: 83.100%
# Epoch 32/182
# Training loss: 0.340, Training accuracy: 88.113%
# Validation loss: 0.676, Validation accuracy: 78.980%
# Epoch 33/182
# Training loss: 0.330, Training accuracy: 88.353%
# Validation loss: 0.592, Validation accuracy: 80.900%
# Epoch 34/182
# Training loss: 0.324, Training accuracy: 88.696%
# Validation loss: 0.570, Validation accuracy: 81.680%
# Epoch 35/182
# Training loss: 0.320, Training accuracy: 88.827%
# Validation loss: 0.541, Validation accuracy: 82.820%
# Epoch 36/182
# Training loss: 0.322, Training accuracy: 88.736%
# Validation loss: 0.520, Validation accuracy: 82.320%
# Epoch 37/182
# Training loss: 0.309, Training accuracy: 89.282%
# Validation loss: 0.541, Validation accuracy: 82.480%
# Epoch 38/182
# Training loss: 0.305, Training accuracy: 89.333%
# Validation loss: 0.590, Validation accuracy: 81.740%
# Epoch 39/182
# Training loss: 0.306, Training accuracy: 89.256%
# Validation loss: 0.652, Validation accuracy: 79.040%
# Epoch 40/182
# Training loss: 0.300, Training accuracy: 89.551%
# Validation loss: 0.721, Validation accuracy: 76.980%
# Epoch 41/182
# Training loss: 0.293, Training accuracy: 89.751%
# Validation loss: 0.540, Validation accuracy: 82.860%
# Epoch 42/182
# Training loss: 0.287, Training accuracy: 89.978%
# Validation loss: 0.629, Validation accuracy: 80.700%
# Epoch 43/182
# Training loss: 0.288, Training accuracy: 90.202%
# Validation loss: 0.556, Validation accuracy: 83.160%
# Epoch 44/182
# Training loss: 0.288, Training accuracy: 89.927%
# Validation loss: 0.754, Validation accuracy: 78.240%
# Epoch 45/182
# Training loss: 0.280, Training accuracy: 90.171%
# Validation loss: 0.680, Validation accuracy: 79.060%
# Epoch 46/182
# Training loss: 0.271, Training accuracy: 90.476%
# Validation loss: 0.581, Validation accuracy: 82.020%
# Epoch 47/182
# Training loss: 0.276, Training accuracy: 90.238%
# Validation loss: 0.514, Validation accuracy: 83.280%
# Epoch 48/182
# Training loss: 0.267, Training accuracy: 90.622%
# Validation loss: 0.593, Validation accuracy: 81.140%
# Epoch 49/182
# Training loss: 0.263, Training accuracy: 90.807%
# Validation loss: 0.546, Validation accuracy: 82.380%
# Epoch 50/182
# Training loss: 0.268, Training accuracy: 90.593%
# Validation loss: 0.658, Validation accuracy: 80.360%
# Epoch 51/182
# Training loss: 0.268, Training accuracy: 90.660%
# Validation loss: 0.587, Validation accuracy: 81.420%
# Epoch 52/182
# Training loss: 0.263, Training accuracy: 90.789%
# Validation loss: 0.529, Validation accuracy: 82.920%
# Epoch 53/182
# Training loss: 0.252, Training accuracy: 91.111%
# Validation loss: 0.519, Validation accuracy: 83.880%
# Epoch 54/182
# Training loss: 0.250, Training accuracy: 91.004%
# Validation loss: 0.527, Validation accuracy: 83.540%
# Epoch 55/182
# Training loss: 0.250, Training accuracy: 91.256%
# Validation loss: 0.595, Validation accuracy: 81.660%
# Epoch 56/182
# Training loss: 0.252, Training accuracy: 91.200%
# Validation loss: 0.521, Validation accuracy: 83.720%
# Epoch 57/182
# Training loss: 0.247, Training accuracy: 91.222%
# Validation loss: 0.560, Validation accuracy: 82.500%
# Epoch 58/182
# Training loss: 0.242, Training accuracy: 91.404%
# Validation loss: 0.533, Validation accuracy: 83.800%
# Epoch 59/182
# Training loss: 0.243, Training accuracy: 91.467%
# Validation loss: 0.530, Validation accuracy: 82.780%
# Epoch 60/182
# Training loss: 0.244, Training accuracy: 91.440%
# Validation loss: 0.572, Validation accuracy: 81.720%
# Epoch 61/182
# Training loss: 0.239, Training accuracy: 91.564%
# Validation loss: 0.639, Validation accuracy: 80.920%
# Epoch 62/182
# Training loss: 0.234, Training accuracy: 91.747%
# Validation loss: 0.662, Validation accuracy: 79.700%
# Epoch 63/182
# Training loss: 0.239, Training accuracy: 91.540%
# Validation loss: 0.534, Validation accuracy: 83.780%
# Epoch 64/182
# Training loss: 0.238, Training accuracy: 91.578%
# Validation loss: 0.689, Validation accuracy: 79.560%
# Epoch 65/182
# Training loss: 0.236, Training accuracy: 91.662%
# Validation loss: 0.568, Validation accuracy: 83.020%
# Epoch 66/182
# Training loss: 0.230, Training accuracy: 91.851%
# Validation loss: 0.541, Validation accuracy: 82.960%
# Epoch 67/182
# Training loss: 0.233, Training accuracy: 91.720%
# Validation loss: 0.674, Validation accuracy: 80.500%
# Epoch 68/182
# Training loss: 0.227, Training accuracy: 91.987%
# Validation loss: 0.666, Validation accuracy: 81.040%
# Epoch 69/182
# Training loss: 0.230, Training accuracy: 91.849%
# Validation loss: 0.532, Validation accuracy: 84.180%
# Epoch 70/182
# Training loss: 0.225, Training accuracy: 92.064%
# Validation loss: 0.508, Validation accuracy: 84.900%
# Epoch 71/182
# Training loss: 0.227, Training accuracy: 91.924%
# Validation loss: 0.524, Validation accuracy: 83.500%
# Epoch 72/182
# Training loss: 0.225, Training accuracy: 92.211%
# Validation loss: 0.560, Validation accuracy: 83.320%
# Epoch 73/182
# Training loss: 0.222, Training accuracy: 92.096%
# Validation loss: 0.623, Validation accuracy: 80.860%
# Epoch 74/182
# Training loss: 0.221, Training accuracy: 92.218%
# Validation loss: 0.502, Validation accuracy: 84.360%
# Epoch 75/182
# Training loss: 0.219, Training accuracy: 92.227%
# Validation loss: 0.536, Validation accuracy: 83.920%
# Epoch 76/182
# Training loss: 0.219, Training accuracy: 92.296%
# Validation loss: 0.622, Validation accuracy: 82.200%
# Epoch 77/182
# Training loss: 0.222, Training accuracy: 92.240%
# Validation loss: 0.504, Validation accuracy: 84.160%
# Epoch 78/182
# Training loss: 0.217, Training accuracy: 92.378%
# Validation loss: 0.685, Validation accuracy: 80.160%
# Epoch 79/182
# Training loss: 0.216, Training accuracy: 92.353%
# Validation loss: 0.621, Validation accuracy: 80.860%
# Epoch 80/182
# Training loss: 0.220, Training accuracy: 92.240%
# Validation loss: 0.507, Validation accuracy: 84.440%
# Epoch 81/182
# Training loss: 0.214, Training accuracy: 92.502%
# Validation loss: 0.591, Validation accuracy: 81.980%
# Epoch 82/182
# Training loss: 0.212, Training accuracy: 92.464%
# Validation loss: 0.625, Validation accuracy: 81.100%
# Epoch 83/182
# Training loss: 0.211, Training accuracy: 92.491%
# Validation loss: 0.780, Validation accuracy: 77.880%
# Epoch 84/182
# Training loss: 0.214, Training accuracy: 92.551%
# Validation loss: 0.683, Validation accuracy: 80.200%
# Epoch 85/182
# Training loss: 0.207, Training accuracy: 92.791%
# Validation loss: 0.568, Validation accuracy: 83.000%
# Epoch 86/182
# Training loss: 0.211, Training accuracy: 92.651%
# Validation loss: 0.700, Validation accuracy: 80.540%
# Epoch 87/182
# Training loss: 0.207, Training accuracy: 92.829%
# Validation loss: 0.568, Validation accuracy: 83.180%
# Epoch 88/182
# Training loss: 0.209, Training accuracy: 92.660%
# Validation loss: 0.572, Validation accuracy: 84.100%
# Epoch 89/182
# Training loss: 0.205, Training accuracy: 92.702%
# Validation loss: 0.491, Validation accuracy: 84.560%
# Epoch 90/182
# Training loss: 0.208, Training accuracy: 92.691%
# Validation loss: 0.586, Validation accuracy: 83.500%
# Epoch 91/182
# Training loss: 0.205, Training accuracy: 92.878%
# Validation loss: 0.498, Validation accuracy: 84.200%
# Epoch 92/182
# Training loss: 0.198, Training accuracy: 92.991%
# Validation loss: 0.522, Validation accuracy: 83.880%
# Epoch 93/182
# Training loss: 0.202, Training accuracy: 92.922%
# Validation loss: 0.538, Validation accuracy: 84.260%
# Epoch 94/182
# Training loss: 0.202, Training accuracy: 92.896%
# Validation loss: 0.743, Validation accuracy: 79.560%
# Epoch 95/182
# Training loss: 0.207, Training accuracy: 92.758%
# Validation loss: 0.619, Validation accuracy: 81.400%
# Epoch 96/182
# Training loss: 0.204, Training accuracy: 92.802%
# Validation loss: 0.601, Validation accuracy: 83.260%
# Epoch 97/182
# Training loss: 0.201, Training accuracy: 92.880%
# Validation loss: 0.576, Validation accuracy: 83.420%
# Epoch 98/182
# Training loss: 0.201, Training accuracy: 92.929%
# Validation loss: 0.711, Validation accuracy: 78.620%
# Epoch 99/182
# Training loss: 0.202, Training accuracy: 92.927%
# Validation loss: 0.605, Validation accuracy: 82.100%
# Epoch 100/182
# Training loss: 0.203, Training accuracy: 92.789%
# Validation loss: 0.573, Validation accuracy: 82.720%
# Epoch 101/182
# Training loss: 0.198, Training accuracy: 93.151%
# Validation loss: 0.475, Validation accuracy: 84.980%
# Epoch 102/182
# Training loss: 0.196, Training accuracy: 93.120%
# Validation loss: 0.545, Validation accuracy: 84.620%
# Epoch 103/182
# Training loss: 0.203, Training accuracy: 92.849%
# Validation loss: 0.518, Validation accuracy: 84.660%
# Epoch 104/182
# Training loss: 0.194, Training accuracy: 93.171%
# Validation loss: 0.529, Validation accuracy: 83.080%
# Epoch 105/182
# Training loss: 0.190, Training accuracy: 93.240%
# Validation loss: 0.587, Validation accuracy: 82.460%
# Epoch 106/182
# Training loss: 0.193, Training accuracy: 93.151%
# Validation loss: 0.615, Validation accuracy: 82.220%
# Epoch 107/182
# Training loss: 0.193, Training accuracy: 93.180%
# Validation loss: 0.537, Validation accuracy: 83.740%
# Epoch 108/182
# Training loss: 0.198, Training accuracy: 93.013%
# Validation loss: 0.529, Validation accuracy: 83.460%
# Epoch 109/182
# Training loss: 0.197, Training accuracy: 93.087%
# Validation loss: 0.608, Validation accuracy: 81.900%
# Epoch 110/182
# Training loss: 0.191, Training accuracy: 93.307%
# Validation loss: 0.579, Validation accuracy: 82.260%
# Epoch 111/182
# Training loss: 0.190, Training accuracy: 93.342%
# Validation loss: 0.661, Validation accuracy: 81.820%
# Epoch 112/182
# Training loss: 0.192, Training accuracy: 93.336%
# Validation loss: 0.555, Validation accuracy: 83.320%
# Epoch 113/182
# Training loss: 0.194, Training accuracy: 93.093%
# Validation loss: 0.505, Validation accuracy: 85.340%
# Epoch 114/182
# Training loss: 0.198, Training accuracy: 93.064%
# Validation loss: 0.699, Validation accuracy: 79.920%
# Epoch 115/182
# Training loss: 0.191, Training accuracy: 93.273%
# Validation loss: 0.723, Validation accuracy: 80.460%
# Epoch 116/182
# Training loss: 0.189, Training accuracy: 93.371%
# Validation loss: 0.586, Validation accuracy: 82.580%
# Epoch 117/182
# Training loss: 0.194, Training accuracy: 93.160%
# Validation loss: 0.531, Validation accuracy: 83.980%
# Epoch 118/182
# Training loss: 0.187, Training accuracy: 93.476%
# Validation loss: 0.516, Validation accuracy: 84.340%
# Epoch 119/182
# Training loss: 0.195, Training accuracy: 93.158%
# Validation loss: 0.662, Validation accuracy: 80.540%
# Epoch 120/182
# Training loss: 0.191, Training accuracy: 93.316%
# Validation loss: 0.667, Validation accuracy: 80.980%
# Epoch 121/182
# Training loss: 0.191, Training accuracy: 93.356%
# Validation loss: 0.513, Validation accuracy: 84.340%
# Epoch 122/182
# Training loss: 0.188, Training accuracy: 93.451%
# Validation loss: 0.630, Validation accuracy: 81.640%
# Epoch 123/182
# Training loss: 0.186, Training accuracy: 93.440%
# Validation loss: 0.522, Validation accuracy: 84.400%
# Epoch 124/182
# Training loss: 0.189, Training accuracy: 93.382%
# Validation loss: 0.515, Validation accuracy: 84.460%
# Epoch 125/182
# Training loss: 0.190, Training accuracy: 93.387%
# Validation loss: 0.514, Validation accuracy: 84.300%
# Epoch 126/182
# Training loss: 0.185, Training accuracy: 93.580%
# Validation loss: 0.587, Validation accuracy: 82.680%
# Epoch 127/182
# Training loss: 0.185, Training accuracy: 93.502%
# Validation loss: 1.009, Validation accuracy: 74.440%
# Epoch 128/182
# Training loss: 0.189, Training accuracy: 93.404%
# Validation loss: 0.565, Validation accuracy: 83.580%
# Epoch 129/182
# Training loss: 0.183, Training accuracy: 93.542%
# Validation loss: 0.602, Validation accuracy: 82.500%
# Epoch 130/182
# Training loss: 0.188, Training accuracy: 93.398%
# Validation loss: 0.570, Validation accuracy: 82.060%
# Epoch 131/182
# Training loss: 0.183, Training accuracy: 93.662%
# Validation loss: 0.488, Validation accuracy: 85.180%
# Epoch 132/182
# Training loss: 0.183, Training accuracy: 93.691%
# Validation loss: 0.519, Validation accuracy: 83.620%
# Epoch 133/182
# Training loss: 0.182, Training accuracy: 93.562%
# Validation loss: 0.502, Validation accuracy: 84.660%
# Epoch 134/182
# Training loss: 0.186, Training accuracy: 93.391%
# Validation loss: 0.575, Validation accuracy: 83.140%
# Epoch 135/182
# Training loss: 0.178, Training accuracy: 93.756%
# Validation loss: 0.591, Validation accuracy: 82.660%
# Epoch 136/182
# Training loss: 0.190, Training accuracy: 93.273%
# Validation loss: 0.526, Validation accuracy: 84.520%
# Epoch 137/182
# Training loss: 0.191, Training accuracy: 93.309%
# Validation loss: 0.668, Validation accuracy: 79.980%
# Epoch 138/182
# Training loss: 0.176, Training accuracy: 93.893%
# Validation loss: 0.479, Validation accuracy: 85.640%
# Epoch 139/182
# Training loss: 0.180, Training accuracy: 93.651%
# Validation loss: 0.624, Validation accuracy: 81.900%
# Epoch 140/182
# Training loss: 0.181, Training accuracy: 93.660%
# Validation loss: 0.542, Validation accuracy: 83.700%
# Epoch 141/182
# Training loss: 0.182, Training accuracy: 93.724%
# Validation loss: 0.593, Validation accuracy: 82.600%
# Epoch 142/182
# Training loss: 0.178, Training accuracy: 93.780%
# Validation loss: 0.594, Validation accuracy: 82.720%
# Epoch 143/182
# Training loss: 0.183, Training accuracy: 93.656%
# Validation loss: 0.479, Validation accuracy: 84.740%
# Epoch 144/182
# Training loss: 0.178, Training accuracy: 93.680%
# Validation loss: 0.476, Validation accuracy: 85.520%
# Epoch 145/182
# Training loss: 0.184, Training accuracy: 93.527%
# Validation loss: 0.526, Validation accuracy: 84.700%
# Epoch 146/182
# Training loss: 0.179, Training accuracy: 93.736%
# Validation loss: 0.472, Validation accuracy: 85.480%
# Epoch 147/182
# Training loss: 0.180, Training accuracy: 93.738%
# Validation loss: 0.589, Validation accuracy: 82.980%
# Epoch 148/182
# Training loss: 0.182, Training accuracy: 93.613%
# Validation loss: 0.604, Validation accuracy: 82.700%
# Epoch 149/182
# Training loss: 0.183, Training accuracy: 93.562%
# Validation loss: 0.504, Validation accuracy: 85.000%
# Epoch 150/182
# Training loss: 0.176, Training accuracy: 93.724%
# Validation loss: 0.558, Validation accuracy: 83.400%
# Epoch 151/182
# Training loss: 0.180, Training accuracy: 93.644%
# Validation loss: 0.478, Validation accuracy: 85.420%
# Epoch 152/182
# Training loss: 0.175, Training accuracy: 93.920%
# Validation loss: 0.691, Validation accuracy: 81.340%
# Epoch 153/182
# Training loss: 0.176, Training accuracy: 93.907%
# Validation loss: 0.563, Validation accuracy: 83.200%
# Epoch 154/182
# Training loss: 0.175, Training accuracy: 93.853%
# Validation loss: 0.591, Validation accuracy: 83.300%
# Epoch 155/182
# Training loss: 0.173, Training accuracy: 93.893%
# Validation loss: 0.526, Validation accuracy: 84.300%
# Epoch 156/182
# Training loss: 0.182, Training accuracy: 93.591%
# Validation loss: 0.551, Validation accuracy: 83.840%
# Epoch 157/182
# Training loss: 0.183, Training accuracy: 93.620%
# Validation loss: 0.498, Validation accuracy: 85.340%
# Epoch 158/182
# Training loss: 0.174, Training accuracy: 93.836%
# Validation loss: 0.525, Validation accuracy: 84.520%
# Epoch 159/182
# Training loss: 0.173, Training accuracy: 93.862%
# Validation loss: 0.494, Validation accuracy: 85.280%
# Epoch 160/182
# Training loss: 0.168, Training accuracy: 94.156%
# Validation loss: 0.537, Validation accuracy: 83.940%
# Epoch 161/182
# Training loss: 0.178, Training accuracy: 93.847%
# Validation loss: 0.684, Validation accuracy: 80.920%
# Epoch 162/182
# Training loss: 0.178, Training accuracy: 93.736%
# Validation loss: 0.489, Validation accuracy: 85.340%
# Epoch 163/182
# Training loss: 0.174, Training accuracy: 93.762%
# Validation loss: 0.606, Validation accuracy: 83.500%
# Epoch 164/182
# Training loss: 0.172, Training accuracy: 93.967%
# Validation loss: 0.603, Validation accuracy: 83.240%
# Epoch 165/182
# Training loss: 0.172, Training accuracy: 94.031%
# Validation loss: 0.646, Validation accuracy: 81.820%
# Epoch 166/182
# Training loss: 0.173, Training accuracy: 93.991%
# Validation loss: 0.683, Validation accuracy: 81.200%
# Epoch 167/182
# Training loss: 0.183, Training accuracy: 93.613%
# Validation loss: 0.694, Validation accuracy: 80.260%
# Epoch 168/182
# Training loss: 0.175, Training accuracy: 93.900%
# Validation loss: 0.625, Validation accuracy: 81.900%
# Epoch 169/182
# Training loss: 0.171, Training accuracy: 94.009%
# Validation loss: 0.485, Validation accuracy: 85.240%
# Epoch 170/182
# Training loss: 0.173, Training accuracy: 93.836%
# Validation loss: 0.595, Validation accuracy: 82.620%
# Epoch 171/182
# Training loss: 0.178, Training accuracy: 93.767%
# Validation loss: 0.464, Validation accuracy: 85.900%
# Epoch 172/182
# Training loss: 0.175, Training accuracy: 93.864%
# Validation loss: 0.588, Validation accuracy: 83.040%
# Epoch 173/182
# Training loss: 0.166, Training accuracy: 94.158%
# Validation loss: 0.583, Validation accuracy: 82.900%
# Epoch 174/182
# Training loss: 0.170, Training accuracy: 94.084%
# Validation loss: 0.626, Validation accuracy: 81.760%
# Epoch 175/182
# Training loss: 0.178, Training accuracy: 93.749%
# Validation loss: 0.521, Validation accuracy: 84.100%
# Epoch 176/182
# Training loss: 0.164, Training accuracy: 94.213%
# Validation loss: 0.534, Validation accuracy: 84.420%
# Epoch 177/182
# Training loss: 0.170, Training accuracy: 94.076%
# Validation loss: 0.862, Validation accuracy: 78.000%
# Epoch 178/182
# Training loss: 0.176, Training accuracy: 93.807%
# Validation loss: 0.586, Validation accuracy: 82.780%
# Epoch 179/182
# Training loss: 0.179, Training accuracy: 93.718%
# Validation loss: 0.616, Validation accuracy: 81.720%
# Epoch 180/182
# Training loss: 0.181, Training accuracy: 93.627%
# Validation loss: 0.555, Validation accuracy: 83.620%
# Epoch 181/182
# Training loss: 0.161, Training accuracy: 94.367%
# Validation loss: 0.597, Validation accuracy: 82.060%
# Epoch 182/182
# Training loss: 0.171, Training accuracy: 94.022%
# Validation loss: 0.520, Validation accuracy: 84.500%
# Plain Net 20 Finished Training
# Training time(seconds): 2391.695727109909

# %% [markdown]
# <h1>Plain Net 56 学習</h1>

# %%
## Train Plain Net 56

t0 = time.time()

for epoch in range(num_epochs):
    # Training
    plain_net56.train()  # Set the model to training mode
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    if num_epochs == 92:

        optimizer_56 = optim.SGD(plain_net56.parameters(), lr = 0.01, momentum = 0.9, weight_decay = 0.0001)


    for data in train_loader:                                     #enumerateでバッチに番号を振り、iでそれを引っ張ってくる。dataは一個ずつ引っ張り出してくるのではなく一気にバッチで学習する。
        inputs, labels = data                                     #画像データ,正解ラベルのペアになっているのを分解
        inputs, labels = inputs.to(device), labels.to(device)     #GPUに載せる
        optimizer_56.zero_grad()                                     #勾配を0に設定
        outputs = plain_net56(inputs)                                     #インスタンス化したモデルに、入力を加えることで主力を得る
        loss = criterion(outputs, labels)                         #指定した損失関数から損失を得る。この時点ではテンソルであることに注意。
        loss.backward()                                           #得た損失のテンソルから勾配を計算
        optimizer_56.step()                                          #得た勾配からパラメータを更新

        running_loss += loss.item()                               #各データの損失を、テンソルから普通の数字(フロート)に変換し、epochごとの損失を得るために足し合わせる。
        _, predicted = torch.max(outputs.data, 1)                 # 1:データの各クラス間 の最大値を、確率とその値を返す。
        total_train += labels.size(0)                             # バッチに含まれているデータの数を継ぎ足す。
        correct_train += (predicted == labels).sum().item()       # 正解した分のみを正答数に継ぎ足す。

    train_losses_56.append(running_loss / len(train_loader))         # epochごとに、平均損失リストに加えていく。
    train_accuracies_56.append(100 * correct_train / total_train)    # epochごとに正答率リストに加えていく。

    # Validation
    plain_net56.eval()  # Set the model to evaluation mode
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for data in val_loader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = plain_net56(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_losses_56.append(val_loss / len(val_loader))
    val_accuracies_56.append(100 * correct_val / total_val)

    print(f'Epoch {epoch+1}/{num_epochs}')
    print(f'Training loss: {train_losses_56[-1]:.3f}, Training accuracy: {train_accuracies_56[-1]:.3f}%')
    print(f'Validation loss: {val_losses_56[-1]:.3f}, Validation accuracy: {val_accuracies_56[-1]:.3f}%')

print('Plain Net 56 Finished Training')
print("Training time(seconds):", time.time()-t0)
# Out:
# Epoch 1/182
# Training loss: 2.272, Training accuracy: 12.129%
# Validation loss: 2.204, Validation accuracy: 15.540%
# Epoch 2/182
# Training loss: 2.112, Training accuracy: 19.858%
# Validation loss: 2.295, Validation accuracy: 22.340%
# Epoch 3/182
# Training loss: 1.977, Training accuracy: 25.940%
# Validation loss: 1.994, Validation accuracy: 26.160%
# Epoch 4/182
# Training loss: 1.922, Training accuracy: 27.969%
# Validation loss: 1.904, Validation accuracy: 27.860%
# Epoch 5/182
# Training loss: 1.838, Training accuracy: 31.273%
# Validation loss: 1.784, Validation accuracy: 31.620%
# Epoch 6/182
# Training loss: 1.750, Training accuracy: 34.436%
# Validation loss: 1.854, Validation accuracy: 33.120%
# Epoch 7/182
# Training loss: 1.694, Training accuracy: 36.520%
# Validation loss: 1.696, Validation accuracy: 35.760%
# Epoch 8/182
# Training loss: 1.653, Training accuracy: 38.227%
# Validation loss: 1.781, Validation accuracy: 35.400%
# Epoch 9/182
# Training loss: 1.612, Training accuracy: 39.702%
# Validation loss: 1.800, Validation accuracy: 36.300%
# Epoch 10/182
# Training loss: 1.581, Training accuracy: 41.338%
# Validation loss: 1.872, Validation accuracy: 34.200%
# Epoch 11/182
# Training loss: 1.524, Training accuracy: 43.691%
# Validation loss: 1.706, Validation accuracy: 37.600%
# Epoch 12/182
# Training loss: 1.462, Training accuracy: 46.049%
# Validation loss: 1.472, Validation accuracy: 46.200%
# Epoch 13/182
# Training loss: 1.398, Training accuracy: 48.291%
# Validation loss: 1.529, Validation accuracy: 45.580%
# Epoch 14/182
# Training loss: 1.329, Training accuracy: 51.236%
# Validation loss: 1.467, Validation accuracy: 47.000%
# Epoch 15/182
# Training loss: 1.269, Training accuracy: 53.833%
# Validation loss: 1.537, Validation accuracy: 45.060%
# Epoch 16/182
# Training loss: 1.194, Training accuracy: 56.593%
# Validation loss: 1.477, Validation accuracy: 47.360%
# Epoch 17/182
# Training loss: 1.121, Training accuracy: 59.636%
# Validation loss: 1.607, Validation accuracy: 48.980%
# Epoch 18/182
# Training loss: 1.069, Training accuracy: 61.836%
# Validation loss: 1.564, Validation accuracy: 47.800%
# Epoch 19/182
# Training loss: 1.024, Training accuracy: 63.460%
# Validation loss: 1.263, Validation accuracy: 57.160%
# Epoch 20/182
# Training loss: 0.989, Training accuracy: 64.833%
# Validation loss: 1.285, Validation accuracy: 53.060%
# Epoch 21/182
# Training loss: 0.955, Training accuracy: 66.244%
# Validation loss: 0.910, Validation accuracy: 66.880%
# Epoch 22/182
# Training loss: 0.921, Training accuracy: 67.613%
# Validation loss: 1.094, Validation accuracy: 60.020%
# Epoch 23/182
# Training loss: 0.898, Training accuracy: 68.351%
# Validation loss: 1.101, Validation accuracy: 60.900%
# Epoch 24/182
# Training loss: 0.876, Training accuracy: 69.151%
# Validation loss: 0.983, Validation accuracy: 65.260%
# Epoch 25/182
# Training loss: 0.848, Training accuracy: 70.360%
# Validation loss: 0.966, Validation accuracy: 65.100%
# Epoch 26/182
# Training loss: 0.832, Training accuracy: 70.796%
# Validation loss: 0.976, Validation accuracy: 65.000%
# Epoch 27/182
# Training loss: 0.810, Training accuracy: 71.709%
# Validation loss: 1.437, Validation accuracy: 58.560%
# Epoch 28/182
# Training loss: 0.797, Training accuracy: 72.118%
# Validation loss: 1.146, Validation accuracy: 60.580%
# Epoch 29/182
# Training loss: 0.773, Training accuracy: 72.998%
# Validation loss: 0.949, Validation accuracy: 67.440%
# Epoch 30/182
# Training loss: 0.767, Training accuracy: 73.327%
# Validation loss: 1.508, Validation accuracy: 54.940%
# Epoch 31/182
# Training loss: 0.750, Training accuracy: 74.113%
# Validation loss: 0.812, Validation accuracy: 71.940%
# Epoch 32/182
# Training loss: 0.731, Training accuracy: 74.436%
# Validation loss: 0.787, Validation accuracy: 71.940%
# Epoch 33/182
# Training loss: 0.720, Training accuracy: 75.033%
# Validation loss: 0.954, Validation accuracy: 66.700%
# Epoch 34/182
# Training loss: 0.707, Training accuracy: 75.498%
# Validation loss: 0.930, Validation accuracy: 69.060%
# Epoch 35/182
# Training loss: 0.702, Training accuracy: 75.631%
# Validation loss: 0.854, Validation accuracy: 69.520%
# Epoch 36/182
# Training loss: 0.695, Training accuracy: 76.013%
# Validation loss: 1.001, Validation accuracy: 64.560%
# Epoch 37/182
# Training loss: 0.688, Training accuracy: 76.218%
# Validation loss: 1.014, Validation accuracy: 66.620%
# Epoch 38/182
# Training loss: 0.666, Training accuracy: 77.102%
# Validation loss: 1.039, Validation accuracy: 62.200%
# Epoch 39/182
# Training loss: 0.662, Training accuracy: 77.229%
# Validation loss: 0.822, Validation accuracy: 71.240%
# Epoch 40/182
# Training loss: 0.656, Training accuracy: 77.391%
# Validation loss: 0.824, Validation accuracy: 72.400%
# Epoch 41/182
# Training loss: 0.643, Training accuracy: 77.738%
# Validation loss: 0.783, Validation accuracy: 72.640%
# Epoch 42/182
# Training loss: 0.636, Training accuracy: 78.129%
# Validation loss: 0.978, Validation accuracy: 68.340%
# Epoch 43/182
# Training loss: 0.629, Training accuracy: 78.149%
# Validation loss: 0.813, Validation accuracy: 72.080%
# Epoch 44/182
# Training loss: 0.621, Training accuracy: 78.502%
# Validation loss: 1.119, Validation accuracy: 66.100%
# Epoch 45/182
# Training loss: 0.624, Training accuracy: 78.547%
# Validation loss: 0.776, Validation accuracy: 73.600%
# Epoch 46/182
# Training loss: 0.612, Training accuracy: 78.796%
# Validation loss: 0.780, Validation accuracy: 72.440%
# Epoch 47/182
# Training loss: 0.610, Training accuracy: 79.067%
# Validation loss: 1.006, Validation accuracy: 66.220%
# Epoch 48/182
# Training loss: 0.601, Training accuracy: 79.213%
# Validation loss: 1.030, Validation accuracy: 68.560%
# Epoch 49/182
# Training loss: 0.599, Training accuracy: 79.371%
# Validation loss: 0.782, Validation accuracy: 73.020%
# Epoch 50/182
# Training loss: 0.599, Training accuracy: 79.527%
# Validation loss: 0.680, Validation accuracy: 77.140%
# Epoch 51/182
# Training loss: 0.587, Training accuracy: 80.024%
# Validation loss: 0.749, Validation accuracy: 75.960%
# Epoch 52/182
# Training loss: 0.588, Training accuracy: 79.811%
# Validation loss: 1.454, Validation accuracy: 59.940%
# Epoch 53/182
# Training loss: 0.578, Training accuracy: 80.242%
# Validation loss: 0.749, Validation accuracy: 74.280%
# Epoch 54/182
# Training loss: 0.582, Training accuracy: 79.967%
# Validation loss: 0.796, Validation accuracy: 73.640%
# Epoch 55/182
# Training loss: 0.568, Training accuracy: 80.507%
# Validation loss: 0.686, Validation accuracy: 75.920%
# Epoch 56/182
# Training loss: 0.568, Training accuracy: 80.520%
# Validation loss: 0.685, Validation accuracy: 76.160%
# Epoch 57/182
# Training loss: 0.567, Training accuracy: 80.689%
# Validation loss: 0.827, Validation accuracy: 73.900%
# Epoch 58/182
# Training loss: 0.562, Training accuracy: 80.618%
# Validation loss: 0.739, Validation accuracy: 74.280%
# Epoch 59/182
# Training loss: 0.560, Training accuracy: 80.871%
# Validation loss: 0.718, Validation accuracy: 74.680%
# Epoch 60/182
# Training loss: 0.552, Training accuracy: 81.211%
# Validation loss: 1.324, Validation accuracy: 63.380%
# Epoch 61/182
# Training loss: 0.556, Training accuracy: 81.087%
# Validation loss: 0.776, Validation accuracy: 73.880%
# Epoch 62/182
# Training loss: 0.549, Training accuracy: 81.149%
# Validation loss: 0.918, Validation accuracy: 70.600%
# Epoch 63/182
# Training loss: 0.548, Training accuracy: 81.238%
# Validation loss: 0.783, Validation accuracy: 74.300%
# Epoch 64/182
# Training loss: 0.544, Training accuracy: 81.156%
# Validation loss: 1.040, Validation accuracy: 68.580%
# Epoch 65/182
# Training loss: 0.540, Training accuracy: 81.487%
# Validation loss: 0.798, Validation accuracy: 72.840%
# Epoch 66/182
# Training loss: 0.540, Training accuracy: 81.627%
# Validation loss: 0.757, Validation accuracy: 73.300%
# Epoch 67/182
# Training loss: 0.532, Training accuracy: 81.607%
# Validation loss: 0.926, Validation accuracy: 71.140%
# Epoch 68/182
# Training loss: 0.532, Training accuracy: 81.811%
# Validation loss: 0.639, Validation accuracy: 77.760%
# Epoch 69/182
# Training loss: 0.523, Training accuracy: 82.196%
# Validation loss: 0.801, Validation accuracy: 75.300%
# Epoch 70/182
# Training loss: 0.524, Training accuracy: 81.896%
# Validation loss: 0.730, Validation accuracy: 76.100%
# Epoch 71/182
# Training loss: 0.522, Training accuracy: 81.967%
# Validation loss: 0.769, Validation accuracy: 74.420%
# Epoch 72/182
# Training loss: 0.516, Training accuracy: 82.269%
# Validation loss: 0.925, Validation accuracy: 71.000%
# Epoch 73/182
# Training loss: 0.518, Training accuracy: 82.351%
# Validation loss: 0.988, Validation accuracy: 69.800%
# Epoch 74/182
# Training loss: 0.519, Training accuracy: 82.396%
# Validation loss: 0.767, Validation accuracy: 73.980%
# Epoch 75/182
# Training loss: 0.517, Training accuracy: 82.404%
# Validation loss: 0.899, Validation accuracy: 71.600%
# Epoch 76/182
# Training loss: 0.515, Training accuracy: 82.258%
# Validation loss: 0.715, Validation accuracy: 76.360%
# Epoch 77/182
# Training loss: 0.510, Training accuracy: 82.649%
# Validation loss: 1.080, Validation accuracy: 68.420%
# Epoch 78/182
# Training loss: 0.505, Training accuracy: 82.696%
# Validation loss: 0.630, Validation accuracy: 78.320%
# Epoch 79/182
# Training loss: 0.506, Training accuracy: 82.782%
# Validation loss: 0.814, Validation accuracy: 73.220%
# Epoch 80/182
# Training loss: 0.501, Training accuracy: 82.982%
# Validation loss: 0.784, Validation accuracy: 74.740%
# Epoch 81/182
# Training loss: 0.501, Training accuracy: 82.958%
# Validation loss: 0.727, Validation accuracy: 75.980%
# Epoch 82/182
# Training loss: 0.509, Training accuracy: 82.578%
# Validation loss: 0.774, Validation accuracy: 74.100%
# Epoch 83/182
# Training loss: 0.499, Training accuracy: 82.847%
# Validation loss: 0.739, Validation accuracy: 76.420%
# Epoch 84/182
# Training loss: 0.494, Training accuracy: 83.273%
# Validation loss: 0.717, Validation accuracy: 75.660%
# Epoch 85/182
# Training loss: 0.498, Training accuracy: 82.916%
# Validation loss: 0.761, Validation accuracy: 75.300%
# Epoch 86/182
# Training loss: 0.496, Training accuracy: 83.196%
# Validation loss: 0.831, Validation accuracy: 74.560%
# Epoch 87/182
# Training loss: 0.483, Training accuracy: 83.484%
# Validation loss: 0.707, Validation accuracy: 75.340%
# Epoch 88/182
# Training loss: 0.492, Training accuracy: 83.396%
# Validation loss: 1.124, Validation accuracy: 69.100%
# Epoch 89/182
# Training loss: 0.489, Training accuracy: 83.311%
# Validation loss: 0.642, Validation accuracy: 78.040%
# Epoch 90/182
# Training loss: 0.475, Training accuracy: 84.002%
# Validation loss: 0.657, Validation accuracy: 78.200%
# Epoch 91/182
# Training loss: 0.485, Training accuracy: 83.484%
# Validation loss: 0.811, Validation accuracy: 74.040%
# Epoch 92/182
# Training loss: 0.481, Training accuracy: 83.591%
# Validation loss: 0.674, Validation accuracy: 78.100%
# Epoch 93/182
# Training loss: 0.474, Training accuracy: 84.058%
# Validation loss: 0.789, Validation accuracy: 74.160%
# Epoch 94/182
# Training loss: 0.477, Training accuracy: 83.791%
# Validation loss: 0.742, Validation accuracy: 76.340%
# Epoch 95/182
# Training loss: 0.480, Training accuracy: 83.633%
# Validation loss: 0.764, Validation accuracy: 74.980%
# Epoch 96/182
# Training loss: 0.480, Training accuracy: 83.756%
# Validation loss: 0.664, Validation accuracy: 77.720%
# Epoch 97/182
# Training loss: 0.467, Training accuracy: 83.851%
# Validation loss: 0.812, Validation accuracy: 72.820%
# Epoch 98/182
# Training loss: 0.476, Training accuracy: 83.827%
# Validation loss: 0.773, Validation accuracy: 74.600%
# Epoch 99/182
# Training loss: 0.465, Training accuracy: 84.060%
# Validation loss: 0.662, Validation accuracy: 78.000%
# Epoch 100/182
# Training loss: 0.471, Training accuracy: 83.920%
# Validation loss: 0.739, Validation accuracy: 76.900%
# Epoch 101/182
# Training loss: 0.470, Training accuracy: 83.989%
# Validation loss: 0.799, Validation accuracy: 75.100%
# Epoch 102/182
# Training loss: 0.459, Training accuracy: 84.298%
# Validation loss: 0.681, Validation accuracy: 76.880%
# Epoch 103/182
# Training loss: 0.464, Training accuracy: 84.249%
# Validation loss: 0.643, Validation accuracy: 79.140%
# Epoch 104/182
# Training loss: 0.463, Training accuracy: 84.422%
# Validation loss: 0.848, Validation accuracy: 72.800%
# Epoch 105/182
# Training loss: 0.458, Training accuracy: 84.464%
# Validation loss: 0.781, Validation accuracy: 73.940%
# Epoch 106/182
# Training loss: 0.462, Training accuracy: 84.278%
# Validation loss: 0.702, Validation accuracy: 76.620%
# Epoch 107/182
# Training loss: 0.465, Training accuracy: 84.149%
# Validation loss: 0.870, Validation accuracy: 72.760%
# Epoch 108/182
# Training loss: 0.455, Training accuracy: 84.542%
# Validation loss: 0.640, Validation accuracy: 78.840%
# Epoch 109/182
# Training loss: 0.458, Training accuracy: 84.464%
# Validation loss: 0.695, Validation accuracy: 76.180%
# Epoch 110/182
# Training loss: 0.456, Training accuracy: 84.411%
# Validation loss: 0.867, Validation accuracy: 72.240%
# Epoch 111/182
# Training loss: 0.458, Training accuracy: 84.251%
# Validation loss: 0.891, Validation accuracy: 73.860%
# Epoch 112/182
# Training loss: 0.451, Training accuracy: 84.638%
# Validation loss: 0.702, Validation accuracy: 76.080%
# Epoch 113/182
# Training loss: 0.460, Training accuracy: 84.267%
# Validation loss: 0.837, Validation accuracy: 74.760%
# Epoch 114/182
# Training loss: 0.447, Training accuracy: 84.751%
# Validation loss: 1.046, Validation accuracy: 70.540%
# Epoch 115/182
# Training loss: 0.453, Training accuracy: 84.720%
# Validation loss: 0.802, Validation accuracy: 74.880%
# Epoch 116/182
# Training loss: 0.448, Training accuracy: 84.907%
# Validation loss: 0.706, Validation accuracy: 77.980%
# Epoch 117/182
# Training loss: 0.453, Training accuracy: 84.504%
# Validation loss: 1.003, Validation accuracy: 70.320%
# Epoch 118/182
# Training loss: 0.443, Training accuracy: 84.922%
# Validation loss: 0.567, Validation accuracy: 80.780%
# Epoch 119/182
# Training loss: 0.447, Training accuracy: 84.913%
# Validation loss: 0.897, Validation accuracy: 69.960%
# Epoch 120/182
# Training loss: 0.444, Training accuracy: 85.096%
# Validation loss: 0.777, Validation accuracy: 76.320%
# Epoch 121/182
# Training loss: 0.451, Training accuracy: 84.624%
# Validation loss: 0.623, Validation accuracy: 79.400%
# Epoch 122/182
# Training loss: 0.443, Training accuracy: 84.898%
# Validation loss: 0.795, Validation accuracy: 75.460%
# Epoch 123/182
# Training loss: 0.446, Training accuracy: 84.818%
# Validation loss: 0.757, Validation accuracy: 76.100%
# Epoch 124/182
# Training loss: 0.444, Training accuracy: 84.842%
# Validation loss: 0.614, Validation accuracy: 78.900%
# Epoch 125/182
# Training loss: 0.440, Training accuracy: 84.944%
# Validation loss: 0.838, Validation accuracy: 73.820%
# Epoch 126/182
# Training loss: 0.434, Training accuracy: 85.309%
# Validation loss: 0.844, Validation accuracy: 73.660%
# Epoch 127/182
# Training loss: 0.437, Training accuracy: 85.004%
# Validation loss: 0.707, Validation accuracy: 77.540%
# Epoch 128/182
# Training loss: 0.439, Training accuracy: 85.138%
# Validation loss: 0.600, Validation accuracy: 79.980%
# Epoch 129/182
# Training loss: 0.433, Training accuracy: 85.176%
# Validation loss: 0.587, Validation accuracy: 80.520%
# Epoch 130/182
# Training loss: 0.437, Training accuracy: 85.178%
# Validation loss: 0.668, Validation accuracy: 77.320%
# Epoch 131/182
# Training loss: 0.444, Training accuracy: 84.958%
# Validation loss: 0.674, Validation accuracy: 77.720%
# Epoch 132/182
# Training loss: 0.432, Training accuracy: 85.284%
# Validation loss: 0.705, Validation accuracy: 77.840%
# Epoch 133/182
# Training loss: 0.431, Training accuracy: 85.411%
# Validation loss: 0.750, Validation accuracy: 77.460%
# Epoch 134/182
# Training loss: 0.437, Training accuracy: 85.242%
# Validation loss: 0.718, Validation accuracy: 76.900%
# Epoch 135/182
# Training loss: 0.430, Training accuracy: 85.336%
# Validation loss: 0.745, Validation accuracy: 76.140%
# Epoch 136/182
# Training loss: 0.427, Training accuracy: 85.509%
# Validation loss: 0.695, Validation accuracy: 76.920%
# Epoch 137/182
# Training loss: 0.430, Training accuracy: 85.469%
# Validation loss: 0.944, Validation accuracy: 69.500%
# Epoch 138/182
# Training loss: 0.429, Training accuracy: 85.240%
# Validation loss: 1.120, Validation accuracy: 67.720%
# Epoch 139/182
# Training loss: 0.426, Training accuracy: 85.536%
# Validation loss: 0.701, Validation accuracy: 76.960%
# Epoch 140/182
# Training loss: 0.436, Training accuracy: 85.149%
# Validation loss: 0.608, Validation accuracy: 80.080%
# Epoch 141/182
# Training loss: 0.426, Training accuracy: 85.482%
# Validation loss: 0.814, Validation accuracy: 74.220%
# Epoch 142/182
# Training loss: 0.433, Training accuracy: 85.471%
# Validation loss: 0.700, Validation accuracy: 77.580%
# Epoch 143/182
# Training loss: 0.422, Training accuracy: 85.678%
# Validation loss: 0.942, Validation accuracy: 70.720%
# Epoch 144/182
# Training loss: 0.422, Training accuracy: 85.538%
# Validation loss: 0.871, Validation accuracy: 72.600%
# Epoch 145/182
# Training loss: 0.428, Training accuracy: 85.442%
# Validation loss: 0.641, Validation accuracy: 78.540%
# Epoch 146/182
# Training loss: 0.428, Training accuracy: 85.493%
# Validation loss: 0.801, Validation accuracy: 75.400%
# Epoch 147/182
# Training loss: 0.418, Training accuracy: 85.749%
# Validation loss: 0.630, Validation accuracy: 79.840%
# Epoch 148/182
# Training loss: 0.420, Training accuracy: 85.736%
# Validation loss: 0.642, Validation accuracy: 79.140%
# Epoch 149/182
# Training loss: 0.423, Training accuracy: 85.538%
# Validation loss: 1.016, Validation accuracy: 70.840%
# Epoch 150/182
# Training loss: 0.421, Training accuracy: 85.711%
# Validation loss: 0.614, Validation accuracy: 78.840%
# Epoch 151/182
# Training loss: 0.416, Training accuracy: 85.936%
# Validation loss: 0.641, Validation accuracy: 79.860%
# Epoch 152/182
# Training loss: 0.425, Training accuracy: 85.591%
# Validation loss: 0.555, Validation accuracy: 81.360%
# Epoch 153/182
# Training loss: 0.425, Training accuracy: 85.387%
# Validation loss: 1.005, Validation accuracy: 69.320%
# Epoch 154/182
# Training loss: 0.427, Training accuracy: 85.476%
# Validation loss: 0.656, Validation accuracy: 78.700%
# Epoch 155/182
# Training loss: 0.420, Training accuracy: 85.627%
# Validation loss: 0.793, Validation accuracy: 73.380%
# Epoch 156/182
# Training loss: 0.427, Training accuracy: 85.549%
# Validation loss: 0.611, Validation accuracy: 79.420%
# Epoch 157/182
# Training loss: 0.420, Training accuracy: 85.707%
# Validation loss: 0.727, Validation accuracy: 76.440%
# Epoch 158/182
# Training loss: 0.411, Training accuracy: 86.000%
# Validation loss: 0.688, Validation accuracy: 78.080%
# Epoch 159/182
# Training loss: 0.417, Training accuracy: 85.691%
# Validation loss: 0.679, Validation accuracy: 77.280%
# Epoch 160/182
# Training loss: 0.415, Training accuracy: 85.809%
# Validation loss: 0.940, Validation accuracy: 71.080%
# Epoch 161/182
# Training loss: 0.417, Training accuracy: 85.811%
# Validation loss: 0.943, Validation accuracy: 70.980%
# Epoch 162/182
# Training loss: 0.416, Training accuracy: 85.851%
# Validation loss: 0.582, Validation accuracy: 80.540%
# Epoch 163/182
# Training loss: 0.413, Training accuracy: 85.969%
# Validation loss: 2.153, Validation accuracy: 52.620%
# Epoch 164/182
# Training loss: 0.418, Training accuracy: 85.751%
# Validation loss: 0.972, Validation accuracy: 71.780%
# Epoch 165/182
# Training loss: 0.412, Training accuracy: 86.009%
# Validation loss: 0.620, Validation accuracy: 80.260%
# Epoch 166/182
# Training loss: 0.409, Training accuracy: 85.998%
# Validation loss: 0.598, Validation accuracy: 79.620%
# Epoch 167/182
# Training loss: 0.411, Training accuracy: 85.927%
# Validation loss: 0.787, Validation accuracy: 74.660%
# Epoch 168/182
# Training loss: 0.408, Training accuracy: 86.133%
# Validation loss: 0.910, Validation accuracy: 70.880%
# Epoch 169/182
# Training loss: 0.412, Training accuracy: 86.053%
# Validation loss: 0.795, Validation accuracy: 76.800%
# Epoch 170/182
# Training loss: 0.401, Training accuracy: 86.367%
# Validation loss: 0.564, Validation accuracy: 80.240%
# Epoch 171/182
# Training loss: 0.414, Training accuracy: 85.798%
# Validation loss: 0.794, Validation accuracy: 74.920%
# Epoch 172/182
# Training loss: 0.412, Training accuracy: 86.102%
# Validation loss: 0.979, Validation accuracy: 69.000%
# Epoch 173/182
# Training loss: 0.405, Training accuracy: 86.176%
# Validation loss: 0.752, Validation accuracy: 76.260%
# Epoch 174/182
# Training loss: 0.406, Training accuracy: 86.060%
# Validation loss: 0.982, Validation accuracy: 70.120%
# Epoch 175/182
# Training loss: 0.404, Training accuracy: 86.351%
# Validation loss: 0.617, Validation accuracy: 80.100%
# Epoch 176/182
# Training loss: 0.408, Training accuracy: 86.056%
# Validation loss: 0.800, Validation accuracy: 74.280%
# Epoch 177/182
# Training loss: 0.408, Training accuracy: 86.098%
# Validation loss: 0.628, Validation accuracy: 78.700%
# Epoch 178/182
# Training loss: 0.405, Training accuracy: 86.100%
# Validation loss: 0.641, Validation accuracy: 78.680%
# Epoch 179/182
# Training loss: 0.408, Training accuracy: 85.982%
# Validation loss: 0.730, Validation accuracy: 76.120%
# Epoch 180/182
# Training loss: 0.402, Training accuracy: 86.358%
# Validation loss: 0.671, Validation accuracy: 77.480%
# Epoch 181/182
# Training loss: 0.404, Training accuracy: 86.282%
# Validation loss: 0.740, Validation accuracy: 76.380%
# Epoch 182/182
# Training loss: 0.413, Training accuracy: 86.027%
# Validation loss: 0.873, Validation accuracy: 72.040%
# Plain Net 56 Finished Training
# Training time(seconds): 5042.292867422104

# %% [markdown]
# <h1>結果のプロット</h1>

# %%
# Plot the training and validation loss
plt.figure(figsize=(12, 4))                                              # 横12インチ、縦4インチのグラフを作成
plt.subplot(1, 2, 1)                                                     # 1行 2列にグラフを表示、最初に左からグラフをプロットする。
plt.plot(range(1, num_epochs+1), train_losses_20, label='20 Training Loss', color = 'blue', linestyle = 'dashed')
plt.plot(range(1, num_epochs+1), train_losses_56,label='56 Training Loss' , color = 'magenta', linestyle = 'dashed')
plt.plot(range(1, num_epochs+1), val_losses_20,label='20 Validation Loss' , color = 'blue')
plt.plot(range(1, num_epochs+1), val_losses_56 ,label='56 Validation Loss', color = 'magenta')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), train_accuracies_20, label='20 Training Accuracy', color = 'blue', linestyle = 'dashed')
plt.plot(range(1, num_epochs+1), train_accuracies_56,  label='56 Training Accuracy', color = 'magenta', linestyle = 'dashed')
plt.plot(range(1, num_epochs+1), val_accuracies_20, label='20 Validation Accuracy', color = 'blue')
plt.plot(range(1, num_epochs+1), val_accuracies_56, label='56 Training Accuracy', color = 'magenta')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

plt.show()
